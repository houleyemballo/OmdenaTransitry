# %%
pip install nltk

# %%
import pandas as pd
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
from collections import Counter

# Download stopwords if not already downloaded
nltk.download('stopwords')
nltk.download('punkt')
# Function to preprocess text and extract words
def extract_words(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Filter out stopwords and non-alphabetic characters
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalpha() and word not in stop_words]
    
    return words

# Path to the Excel file
excel_file = 'AgricultureForestryOther.xlsx'

# Column name in the Excel file
column_name = 'Name'  # Replace with the actual column name

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Extract words from the specified column and create a list of all words
all_words = []
for text in df[column_name]:
    if pd.notnull(text):
        words = extract_words(str(text))
        all_words.extend(words)

# Count the occurrence of each word
word_counts = Counter(all_words)

# Get the most common words and their frequencies
num_common_words = 10  # Specify the number of most common words to retrieve
most_common_words = word_counts.most_common(num_common_words)

# Print the most common words and their frequencies
for word, frequency in most_common_words:
    print(word, ":", frequency)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\cobb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\cobb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\cobb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# project : 519
# management : 332
# rice : 274
# cultivation : 270
# water : 238
# adjusted : 150
# forest : 142
# carbon : 116
# afforestation : 103
# county : 62

# %%
# Function to preprocess text and extract words
def extract_words(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Filter out stopwords and non-alphabetic characters
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalpha() and word not in stop_words]
    
    return words

# Path to the Excel file
excel_file = 'ChemicalIndustry.xlsx'

# Column name in the Excel file
column_name = 'Name'  # Replace with the actual column name

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Extract words from the specified column and create a list of all words
all_words = []
for text in df[column_name]:
    if pd.notnull(text):
        words = extract_words(str(text))
        all_words.extend(words)

# Count the occurrence of each word
word_counts = Counter(all_words)

# Get the most common words and their frequencies
num_common_words = 10  # Specify the number of most common words to retrieve
most_common_words = word_counts.most_common(num_common_words)

# Print the most common words and their frequencies
for word, frequency in most_common_words:
    print(word, ":", frequency)
# Out:
# project : 13
# abatement : 6
# cer : 6
# conversion : 6
# limited : 4
# reduction : 4
# ael : 4
# biodiesel : 3
# omnia : 3
# nitrous : 3

# %%
# Function to preprocess text and extract words
def extract_words(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Filter out stopwords and non-alphabetic characters
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalpha() and word not in stop_words]
    
    return words

# Path to the Excel file
excel_file = 'Construction.xlsx'

# Column name in the Excel file
column_name = 'Name'  # Replace with the actual column name

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Extract words from the specified column and create a list of all words
all_words = []
for text in df[column_name]:
    if pd.notnull(text):
        words = extract_words(str(text))
        all_words.extend(words)

# Count the occurrence of each word
word_counts = Counter(all_words)

# Get the most common words and their frequencies
num_common_words = 10  # Specify the number of most common words to retrieve
most_common_words = word_counts.most_common(num_common_words)

# Print the most common words and their frequencies
for word, frequency in most_common_words:
    print(word, ":", frequency)
# Out:
# concrete : 5
# capture : 3
# cement : 2
# carbon : 2
# reductions : 2
# utilization : 2
# project : 2
# use : 2
# production : 1
# reduction : 1

# %%
# Function to preprocess text and extract words
def extract_words(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Filter out stopwords and non-alphabetic characters
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalpha() and word not in stop_words]
    
    return words

# Path to the Excel file
excel_file = 'EnergyDemand.xlsx'

# Column name in the Excel file
column_name = 'Name'  # Replace with the actual column name

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Extract words from the specified column and create a list of all words
all_words = []
for text in df[column_name]:
    if pd.notnull(text):
        words = extract_words(str(text))
        all_words.extend(words)

# Count the occurrence of each word
word_counts = Counter(all_words)

# Get the most common words and their frequencies
num_common_words = 10  # Specify the number of most common words to retrieve
most_common_words = word_counts.most_common(num_common_words)

# Print the most common words and their frequencies
for word, frequency in most_common_words:
    print(word, ":", frequency)
# Out:
# improved : 174
# project : 142
# cookstove : 125
# cook : 104
# phase : 89
# stove : 88
# distribution : 74
# program : 73
# cookstoves : 69
# efficiency : 62

# %%
# Function to preprocess text and extract words
def extract_words(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Filter out stopwords and non-alphabetic characters
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalpha() and word not in stop_words]
    
    return words

# Path to the Excel file
excel_file = 'EnergyDistribution.xlsx'

# Column name in the Excel file
column_name = 'Name'  # Replace with the actual column name

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Extract words from the specified column and create a list of all words
all_words = []
for text in df[column_name]:
    if pd.notnull(text):
        words = extract_words(str(text))
        all_words.extend(words)

# Count the occurrence of each word
word_counts = Counter(all_words)

# Get the most common words and their frequencies
num_common_words = 10  # Specify the number of most common words to retrieve
most_common_words = word_counts.most_common(num_common_words)

# Print the most common words and their frequencies
for word, frequency in most_common_words:
    print(word, ":", frequency)
# Out:
# project : 5
# cement : 3
# plant : 3
# biomass : 3
# energy : 2
# generation : 2
# weatherization : 2
# single : 2
# virginia : 2
# cemex : 2

# %%
# Function to preprocess text and extract words
def extract_words(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Filter out stopwords and non-alphabetic characters
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalpha() and word not in stop_words]
    
    return words

# Path to the Excel file
excel_file = 'EnergyIndustries.xlsx'

# Column name in the Excel file
column_name = 'Name'  # Replace with the actual column name

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Extract words from the specified column and create a list of all words
all_words = []
for text in df[column_name]:
    if pd.notnull(text):
        words = extract_words(str(text))
        all_words.extend(words)

# Count the occurrence of each word
word_counts = Counter(all_words)

# Get the most common words and their frequencies
num_common_words = 10  # Specify the number of most common words to retrieve
most_common_words = word_counts.most_common(num_common_words)

# Print the most common words and their frequencies
for word, frequency in most_common_words:
    print(word, ":", frequency)
# Out:
# project : 1190
# power : 736
# wind : 601
# mw : 325
# energy : 216
# india : 212
# plant : 187
# generation : 174
# solar : 171
# limited : 143

# %%
# Function to preprocess text and extract words
def extract_words(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Filter out stopwords and non-alphabetic characters
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalpha() and word not in stop_words]
    
    return words

# Path to the Excel file
excel_file = 'FugitiveEmissionsFuels.xlsx'

# Column name in the Excel file
column_name = 'Name'  # Replace with the actual column name

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Extract words from the specified column and create a list of all words
all_words = []
for text in df[column_name]:
    if pd.notnull(text):
        words = extract_words(str(text))
        all_words.extend(words)

# Count the occurrence of each word
word_counts = Counter(all_words)

# Get the most common words and their frequencies
num_common_words = 10  # Specify the number of most common words to retrieve
most_common_words = word_counts.most_common(num_common_words)

# Print the most common words and their frequencies
for word, frequency in most_common_words:
    print(word, ":", frequency)
# Out:
# gas : 19
# utilization : 11
# distribution : 8
# network : 8
# reducing : 7
# leakages : 7
# within : 7
# bangladesh : 7
# project : 7
# methane : 6

# %%
# Function to preprocess text and extract words
def extract_words(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Filter out stopwords and non-alphabetic characters
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalpha() and word not in stop_words]
    
    return words

# Path to the Excel file
excel_file = 'FugitiveEmissionsHaloEtc.xlsx'

# Column name in the Excel file
column_name = 'Name'  # Replace with the actual column name

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Extract words from the specified column and create a list of all words
all_words = []
for text in df[column_name]:
    if pd.notnull(text):
        words = extract_words(str(text))
        all_words.extend(words)

# Count the occurrence of each word
word_counts = Counter(all_words)

# Get the most common words and their frequencies
num_common_words = 10  # Specify the number of most common words to retrieve
most_common_words = word_counts.most_common(num_common_words)

# Print the most common words and their frequencies
for word, frequency in most_common_words:
    print(word, ":", frequency)
# Out:
# project : 3
# tradewater : 2
# international : 2
# south : 2
# africa : 2
# honduras : 1
# dominican : 1
# republic : 1
# yingpeng : 1
# decompostion : 1

# %%
# Function to preprocess text and extract words
def extract_words(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Filter out stopwords and non-alphabetic characters
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalpha() and word not in stop_words]
    
    return words

# Path to the Excel file
excel_file = 'Livestock.xlsx'

# Column name in the Excel file
column_name = 'Name'  # Replace with the actual column name

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Extract words from the specified column and create a list of all words
all_words = []
for text in df[column_name]:
    if pd.notnull(text):
        words = extract_words(str(text))
        all_words.extend(words)

# Count the occurrence of each word
word_counts = Counter(all_words)

# Get the most common words and their frequencies
num_common_words = 10  # Specify the number of most common words to retrieve
most_common_words = word_counts.most_common(num_common_words)

# Print the most common words and their frequencies
for word, frequency in most_common_words:
    print(word, ":", frequency)
# Out:
# project : 39
# biogas : 14
# recovery : 14
# ghg : 13
# mitigation : 13
# awms : 10
# farm : 10
# dairy : 10
# methane : 10
# management : 8

# %%
# Function to preprocess text and extract words
def extract_words(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Filter out stopwords and non-alphabetic characters
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalpha() and word not in stop_words]
    
    return words

# Path to the Excel file
excel_file = 'ManufacturingIndustries.xlsx'

# Column name in the Excel file
column_name = 'Name'  # Replace with the actual column name

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Extract words from the specified column and create a list of all words
all_words = []
for text in df[column_name]:
    if pd.notnull(text):
        words = extract_words(str(text))
        all_words.extend(words)

# Count the occurrence of each word
word_counts = Counter(all_words)

# Get the most common words and their frequencies
num_common_words = 10  # Specify the number of most common words to retrieve
most_common_words = word_counts.most_common(num_common_words)

# Print the most common words and their frequencies
for word, frequency in most_common_words:
    print(word, ":", frequency)
# Out:
# project : 25
# aac : 11
# cement : 11
# power : 9
# manufacturing : 8
# waste : 7
# heat : 7
# blocks : 6
# energy : 6
# generation : 5

# %%
# Function to preprocess text and extract words
def extract_words(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Filter out stopwords and non-alphabetic characters
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalpha() and word not in stop_words]
    
    return words

# Path to the Excel file
excel_file = 'MetalProduction.xlsx'

# Column name in the Excel file
column_name = 'Name'  # Replace with the actual column name

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Extract words from the specified column and create a list of all words
all_words = []
for text in df[column_name]:
    if pd.notnull(text):
        words = extract_words(str(text))
        all_words.extend(words)

# Count the occurrence of each word
word_counts = Counter(all_words)

# Get the most common words and their frequencies
num_common_words = 10  # Specify the number of most common words to retrieve
most_common_words = word_counts.most_common(num_common_words)

# Print the most common words and their frequencies
for word, frequency in most_common_words:
    print(word, ":", frequency)
# Out:
# reduction : 2
# emission : 2
# pt : 2
# aluminium : 2
# amg : 1
# ohio : 1
# complex : 1
# ghg : 1
# emissions : 1
# project : 1

# %%
# Function to preprocess text and extract words
def extract_words(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Filter out stopwords and non-alphabetic characters
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalpha() and word not in stop_words]
    
    return words

# Path to the Excel file
excel_file = 'MiningMineralProduction.xlsx'

# Column name in the Excel file
column_name = 'Name'  # Replace with the actual column name

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Extract words from the specified column and create a list of all words
all_words = []
for text in df[column_name]:
    if pd.notnull(text):
        words = extract_words(str(text))
        all_words.extend(words)

# Count the occurrence of each word
word_counts = Counter(all_words)

# Get the most common words and their frequencies
num_common_words = 10  # Specify the number of most common words to retrieve
most_common_words = word_counts.most_common(num_common_words)

# Print the most common words and their frequencies
for word, frequency in most_common_words:
    print(word, ":", frequency)
# Out:
# utilization : 29
# methane : 12
# mine : 8
# project : 8
# coal : 6
# coalmine : 6
# capture : 3
# hugo : 3
# utilisation : 2
# power : 2

# %%
# Function to preprocess text and extract words
def extract_words(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Filter out stopwords and non-alphabetic characters
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalpha() and word not in stop_words]
    
    return words

# Path to the Excel file
excel_file = 'Transport.xlsx'

# Column name in the Excel file
column_name = 'Name'  # Replace with the actual column name

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Extract words from the specified column and create a list of all words
all_words = []
for text in df[column_name]:
    if pd.notnull(text):
        words = extract_words(str(text))
        all_words.extend(words)

# Count the occurrence of each word
word_counts = Counter(all_words)

# Get the most common words and their frequencies
num_common_words = 10  # Specify the number of most common words to retrieve
most_common_words = word_counts.most_common(num_common_words)

# Print the most common words and their frequencies
for word, frequency in most_common_words:
    print(word, ":", frequency)
# Out:
# project : 12
# electric : 8
# ev : 7
# grouped : 6
# vehicle : 6
# vehicles : 5
# india : 5
# charging : 4
# charger : 3
# aggregation : 3

# %%
# Function to preprocess text and extract words
def extract_words(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Filter out stopwords and non-alphabetic characters
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalpha() and word not in stop_words]
    
    return words

# Path to the Excel file
excel_file = 'WasteHandlingDisposal.xlsx'

# Column name in the Excel file
column_name = 'Name'  # Replace with the actual column name

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file)

# Extract words from the specified column and create a list of all words
all_words = []
for text in df[column_name]:
    if pd.notnull(text):
        words = extract_words(str(text))
        all_words.extend(words)

# Count the occurrence of each word
word_counts = Counter(all_words)

# Get the most common words and their frequencies
num_common_words = 10  # Specify the number of most common words to retrieve
most_common_words = word_counts.most_common(num_common_words)

# Print the most common words and their frequencies
for word, frequency in most_common_words:
    print(word, ":", frequency)
# Out:
# project : 254
# landfill : 111
# biogas : 83
# recovery : 72
# gas : 71
# power : 65
# utilization : 59
# treatment : 47
# generation : 45
# methane : 44
